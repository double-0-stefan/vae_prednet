# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
% cd /content/drive/My\ Drive/vae_prednet/
# Out:
# /content/drive/My Drive/vae_prednet

# %%
# !pip install kornia
# Out:
# ...
#      |████████████████████████████████| 122kB 2.8MB/s
# ...

# %%
# !python main.py -m stl10_freqs.yaml
# Out:
# 2019-11-25:15:16:26,92 INFO     [main.py:25] Namespace(config='stl10_freqs.yaml')
# 2019-11-25:15:16:26,94 INFO     [main.py:39] Training
# 2019-11-25:15:16:26,94 INFO     [main.py:40] Reading permutation : 0 of 1
# {'b': 200,
#  'beta': 10.0,
#  'conv': True,
#  'dataset': 'stl10',
#  'dynamic': False,
#  'e': 25000,
#  'early_stopping': True,
#  'elbo_loss': True,
#  'enc_h': [512, 600],
#  'enc_temp': 0.67,
#  'err_noise': True,
#  'exp_name': 'stl10_freq',
#  'foveate': False,
#  'freq_based': True,
#  'generate_data': False,
#  'gpu': True,
#  'h_label': '512',
#  'imdim': (3, 96, 96),
#  'interactive': False,
#  'layers': 2,
#  'lr': 0.0005,
#  'model_name': 'l2_stl10_pnt1_vae1_normal_z52_52_h512_c100000_b10_ld100_elboTrue',
#  'n_actions': 2,
#  'nz_con': [32, 32, 0],
#  'nz_dis': [[10, 10], [10, 10], 0],
#  'patience': 5,
#  'plot_iter': 100,
#  'prednet': True,
#  'rotating': False,
#  'sequences': False,
#  'start_hi': 2000,
#  'train_fx': False,
#  'train_gx': True,
# ...
