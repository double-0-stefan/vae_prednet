# %%
# set-up colab
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/My\ Drive/vae_prednet
# !git config --global user.email 'stefpb@gmail.com'
# !git config --global user.name 'Stefan Brugger'
# !pip install kornia
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# [Errno 2] No such file or directory: 'drive/My Drivevae_prednet'
# /content
# ...
#      |████████████████████████████████| 143kB 2.7MB/s
# ...

# %%
# !git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/double-0-stefan/vae_prednet
#    273758b..3e25d64  master     -> origin/master
# Updating 273758b..3e25d64
# Fast-forward
#  model.py | 3 ++-
#  1 file changed, 2 insertions(+), 1 deletion(-)

# %%
# !python main.py -m pc_cnn.yaml

# %%
# at end or whenever - push changes to github
# !git add .
# !git commit -m 'colab'
# !git push
# Out:
# ^C
# ^C
# Everything up-to-date

# %%
# %pwd
# Out:
# '/content'
